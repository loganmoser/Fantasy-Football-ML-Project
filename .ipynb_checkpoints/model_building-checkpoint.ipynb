# %%
# Import packages
import nflreadpy
import polars as pl
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import tensorflow as tf
from sklearn.linear_model import SGDRegressor, Ridge, LinearRegression
from sklearn.model_selection import RandomizedSearchCV, train_test_split, cross_val_predict
from sklearn.metrics import auc, accuracy_score, root_mean_squared_error, mean_squared_error, silhouette_score
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.base import clone
from sklearn.neighbors import KNeighborsRegressor
from scipy.stats import spearmanr
warnings.filterwarnings('ignore')

# %%
player_data = nflreadpy.load_player_stats(seasons=True, summary_level="reg")
player_demo_data = nflreadpy.load_players()
player_demo_cols_drop = ["display_name","common_first_name", "first_name", "last_name", "short_name", "football_name", 
                    "suffix", "esb_id", "nfl_id", "pfr_id", "pff_id", "otc_id", "espn_id", "smart_id",
                    "position", "position_group", "ngs_position_group", "ngs_position", "headshot", "college_name", 
                    "college_conference", "jersey_number", "last_season", "latest_team", "status", "ngs_status", "ngs_status_short_description",
                    "years_of_experience", "pff_position", "pff_status", "draft_team"]

player_demo_data = player_demo_data.drop(player_demo_cols_drop)

player_data = player_data.join(player_demo_data, left_on="player_id", right_on="gsis_id", how="inner")

# Select unnecessary columns
drop_columns = ["headshot_url", "player_name", "season_type", "gwfg_made", "gwfg_att", "gwfg_missed",
                    "gwfg_blocked", "def_tackles_solo", "def_tackles_with_assist",
                    "def_tackle_assists", "def_tackles_for_loss", "def_tackles_for_loss_yards",
                    "def_fumbles_forced", "def_sacks", "def_sack_yards", "def_qb_hits",
                    "def_interceptions", "def_interception_yards", "def_pass_defended",
                    "def_tds", "def_fumbles", "def_safeties", "punt_returns", "fumble_recovery_own",
                    "fumble_recovery_yards_own", "fumble_recovery_opp", "fumble_recovery_yards_opp",
                    "fumble_recovery_tds", "punt_return_yards", "kickoff_returns", "kickoff_return_yards"
                    ]

player_data_cleaned = player_data.drop(drop_columns)

# Years of experience = current season - rookie season
player_data_cleaned = player_data_cleaned.with_columns(
    (pl.col("season") - pl.col("rookie_season")).alias("years_experience"),
    (pl.col("season") - pl.col("birth_date").str.to_date("%Y-%m-%d").dt.year()).alias("age"),
    (pl.col("draft_round").fill_null(8)), # Fill in for undrafted with more than possible draft rounds
    (pl.col("draft_pick").fill_null(300)), # Fill in for undrafted players with more than possiblepicks
    (pl.col("draft_year").is_not_null().alias("was_drafted"))
)

player_data_cleaned = player_data_cleaned.filter(pl.col("games") > 0)

# Positional columns
qb_cols = ["player_display_name", "season", "games", "completions", "attempts", "passing_yards", "passing_tds",
               "passing_interceptions", "sacks_suffered", "sack_yards_lost", "sack_fumbles",
               "sack_fumbles_lost", "passing_air_yards", "passing_yards_after_catch",
               "passing_first_downs", "passing_epa", "passing_cpoe", "passing_2pt_conversions",
               "pacr", "carries", "rushing_yards", "rushing_tds", "rushing_fumbles",
               "rushing_fumbles_lost", "rushing_first_downs", "rushing_epa",
               "rushing_2pt_conversions", "years_experience", "height", "weight", "draft_round", "draft_pick", "was_drafted",
               "age", "fantasy_points_ppr"]
# RBs, TEs, and WRs had many similar columns so they are combined into skill-position columns
sp_cols = ["player_display_name", "season", "games", "carries", "rushing_yards", "rushing_tds", "rushing_fumbles", 
               "rushing_fumbles_lost", "rushing_first_downs", "rushing_epa", "rushing_2pt_conversions",
               "receptions", "targets", "receiving_yards", "receiving_tds", "receiving_fumbles",
               "receiving_fumbles_lost", "receiving_air_yards", "receiving_yards_after_catch",
               "receiving_first_downs", "receiving_epa", "receiving_2pt_conversions", "racr",
               "target_share", "air_yards_share", "wopr", "years_experience", "height", "weight",
               "draft_round", "draft_pick", "age", "was_drafted", "fantasy_points_ppr"]
   

# Group players by position to build positional models
qbs = player_data_cleaned.filter(pl.col('position') == 'QB')[qb_cols]
rbs = player_data_cleaned.filter(pl.col('position') == 'RB')[sp_cols]
tes = player_data_cleaned.filter(pl.col('position') == 'TE')[sp_cols]
wrs = player_data_cleaned.filter(pl.col('position') == 'WR')[sp_cols]
sps = player_data_cleaned.filter(pl.col("position") != "QB")[sp_cols]

# %%
"""
Feature Engineering for QBs
- Completion %
- yds/att
- td/int ratio
- sacks/gamec
- trends on advanced stats
- Change in fantasy production from previous year

Features for SPs
- yards per carry
- passing targets / rush
- Change in fantasy production from previous year

"""
qbs_after_features_drop = ["completions", "attempts", "sack_yards_lost", "sack_fumbles", "passing_air_yards", "passing_yards_after_catch", "passing_first_downs", "rushing_fumbles", "rushing_first_downs", "rushing_2pt_conversions"]


qbs = qbs.with_columns(
    (pl.col("completions") / pl.col("attempts")).alias("completion_percentage").replace([float("inf"), float("-inf")], 0),
    (pl.col("passing_yards") / pl.col("attempts")).alias("yards_per_attempt").replace([float("inf"), float("-inf")], 0),
    (pl.col("passing_tds") / pl.col("attempts")).alias("TDS/Pass").replace([float("inf"), float("-inf")], 0),
    (pl.col("passing_tds") / pl.col("passing_interceptions")).alias("interception_ratio").replace([float("inf"), float("-inf"), np.nan], 0),
    (pl.col("sacks_suffered") / pl.col("games")).alias("sacks_per_game").replace([float("inf"), float("-inf")], 0),
    (pl.col("passing_cpoe").is_not_null().alias("has_cpoe_data")),
    (pl.col("passing_cpoe").fill_null(0)),
    (pl.col("passing_epa")-pl.col("passing_epa").shift(1).over("player_display_name")).alias("passing_epa_trend").fill_null(0),
    (pl.col("passing_cpoe")-pl.col("passing_cpoe").shift(1).over("player_display_name")).alias("passing_cpoe_trend").fill_null(0),
    (pl.col("fantasy_points_ppr")-pl.col("fantasy_points_ppr").shift(1).over("player_display_name")).alias("one_year_fpp_trend").fill_null(0),
)
rbs = rbs.with_columns(
    (pl.col("rushing_yards") / pl.col("carries")).alias("yards_per_rush").replace([float('inf'), float('-inf')], 0),
    (pl.col("rushing_epa").fill_null(0)),
    (pl.col("targets") / pl.col("carries")).alias("targets/carries").replace([float('inf'), float('-inf')], 0),
    (pl.col("racr").fill_null(0)),
    (pl.col("wopr").fill_null(0)),
    (pl.col("fantasy_points_ppr")-pl.col("fantasy_points_ppr").shift(1).over("player_display_name")).alias("one_year_fpp_trend").fill_null(0),
    (pl.col("carries") + pl.col("targets") >= 300).alias("is_workhorse")
    )
tes = tes.with_columns(
    (pl.col("rushing_yards") / pl.col("carries")).alias("yards_per_rush").replace([float('inf'), float('-inf')], 0),
    (pl.col("rushing_epa").fill_null(0)),
    (pl.col("targets") / pl.col("carries")).alias("targets/carries").replace([float('inf'), float('-inf')], 0),
    (pl.col("racr").fill_null(0)),
    (pl.col("wopr").fill_null(0)),
    (pl.col("fantasy_points_ppr")-pl.col("fantasy_points_ppr").shift(1).over("player_display_name")).alias("one_year_fpp_trend").fill_null(0)
)
wrs = wrs.with_columns(
    (pl.col("rushing_yards") / pl.col("carries")).alias("yards_per_rush").replace([float('inf'), float('-inf')], 0),
    (pl.col("rushing_epa").fill_null(0)),
    (pl.col("targets") / pl.col("carries")).alias("targets/carries").replace([float('inf'), float('-inf')], 0),
    (pl.col("racr").fill_null(0)),
    (pl.col("wopr").fill_null(0)),
    (pl.col("fantasy_points_ppr")-pl.col("fantasy_points_ppr").shift(1).over("player_display_name")).alias("one_year_fpp_trend").fill_null(0)
)

sps = sps.with_columns(
    (pl.col("rushing_yards") / pl.col("carries")).alias("yards_per_rush").replace([float('inf'), float('-inf')], 0),
    (pl.col("rushing_epa").fill_null(0)),
    (pl.col("targets") / pl.col("carries")).alias("targets/carries").replace([float('inf'), float('-inf')], 0),
    (pl.col("racr").fill_null(0)),
    (pl.col("wopr").fill_null(0)),
    (pl.col("fantasy_points_ppr")-pl.col("fantasy_points_ppr").shift(1).over("player_display_name")).alias("one_year_fpp_trend").fill_null(0)
)

# %%
def build_prediction_dataset(
    df: pl.DataFrame,
    target_col: str = "fantasy_points_ppr",
    id_cols: list[str] = ["player_display_name", "season"],
    lag: int = 1
):
    """
    Pairs each season's stats with the NEXT season's target.
    
    2024 stats → 2025 fantasy points
    2023 stats → 2024 fantasy points
    ...all the way back to 1999 stats → 2000 fantasy points
    """
    
    # Everything that isn't an ID or the target is a feature
    feature_cols = [c for c in df.columns if c not in id_cols + [target_col]]
    
    # Left side: the stats (features) — unchanged
    stats = df.select(*id_cols, *feature_cols)
    
    # Right side: the target — shift season back so it aligns with prior year
    targets = df.select(
        "player_display_name",
        (pl.col("season") - lag).alias("season"),  # 2025 becomes 2024, etc.
        target_col
    )
    
    # Join: every year's stats get paired with next year's outcome
    combined = stats.join(
        targets,
        on=["player_display_name", "season"],
        how="inner"  # drops players who don't appear in consecutive years
    )
    
    return combined

# %%
def ttv_scaled(X: pl.DataFrame, y):
    num_pipeline = Pipeline([
        ("imputer", SimpleImputer(strategy="median")), 
        ("standardizer", StandardScaler()),
    ])
    X_cols = X.columns
    # Split data into training, valiation, and testing splits
    train_mask = X["season"] <= 2016
    validation_mask = (X["season"] <=2020) & ~(train_mask)
    test_mask = ~(train_mask) & ~(validation_mask)
    
    X_train, y_train = X.filter(train_mask), y.filter(train_mask)
    X_valid, y_valid = X.filter(validation_mask), y.filter(validation_mask)
    X_test, y_test = X.filter(test_mask), y.filter(test_mask)
    
    X_train = pl.DataFrame(num_pipeline.fit_transform(X_train), schema=X_cols)
    X_valid = pl.DataFrame(num_pipeline.transform(X_valid), schema=X_cols)
    X_test = pl.DataFrame(num_pipeline.transform(X_test), schema=X_cols)

    return X_train, y_train, X_valid, y_valid, X_test, y_test, num_pipeline

# %%
# Find best number of clusters for kmeans
def build_kmeans(X_train: pl.DataFrame):
    scores = []
    num_clusters = np.arange(2,11)
    models = []
    X_copy = X_train
    pca = PCA(n_components=0.9)
    X_copy = pca.fit_transform(X_copy)
    
    for n in num_clusters:
        kmeans = KMeans(n_clusters=n, n_init=10, random_state=42)
        kmeans.fit(X_copy)
        models.append(kmeans)
        scores.append(silhouette_score(X_copy, kmeans.labels_))
    
    scores_df = pl.DataFrame({ "clusters": num_clusters, "scores": scores, "models": models})
    
    best_model = scores_df.sort("scores", descending=True)["models"][0] # This is our best model that will give us the clusters
    
    train_distances = best_model.transform(X_copy) # Final model predictions that will be used as a feature
    
    sns.lineplot(data=scores_df[["clusters", "scores"]], x="clusters", y="scores")
    plt.title("Shilouette Scores")
    plt.show()

    return best_model, pca, X_copy

# %%
def add_kmeans(X_train, X_valid, X_test):
    # Build a kmeans model and use it to scale and transform trainin, validation, and testing data
    model, pca, X_copy = build_kmeans(X_train)
    X_train_clusters = pl.DataFrame(model.transform(X_copy))
    X_train_clusters.columns = [f"cluster_{x+1}_distance" for x in range(model.n_clusters)]
    X_train = X_train.hstack(X_train_clusters)
    
    X_valid_clusters = pl.DataFrame(
        model.transform(
            pca.transform(
               X_valid
            )
        )
    )
    X_valid_clusters.columns = [f"cluster_{x+1}_distance" for x in range(model.n_clusters)]
    X_valid = X_valid.hstack(X_valid_clusters)
    
    X_test_clusters = pl.DataFrame(
        model.transform(
            pca.transform(
                X_test
            )
        )
    )
    X_test_clusters.columns = [f"cluster_{x+1}_distance" for x in range(model.n_clusters)]
    X_test = X_test.hstack(X_test_clusters)

    return X_train, X_valid, X_test, model, pca

# %%
def base_model_predictions(X_train, X_test, X_valid, y_train, y_valid, model_name, model, params = {}):
    pipe = Pipeline([(model_name, model)])
    search = RandomizedSearchCV(pipe, param_distributions=params,
                                cv=10, n_jobs=-1, random_state=42) # RandomizedSearchCV used to find optimal hyperparameters 
    search.fit(X_train, y_train)
    best = search.best_estimator_

    # meta-feature for TRAIN: out-of-fold preds (no leakage)
    train_preds = pl.DataFrame(cross_val_predict(clone(best), X_train, y_train, cv=10, n_jobs=-1))
    train_preds.columns = [f"{str(model).split('(')[0]}_predictions"] # to identify which model made this prediction

    #meta-features for VALID:
    valid_preds = pl.DataFrame(cross_val_predict(clone(best), X_valid, y_valid, cv=10, n_jobs=-1))
    valid_preds.columns = [f"{str(model).split('(')[0]}_predictions"] # to identify which model made this prediction

    # meta-feature for TEST: model trained on full train, applied to unseen test
    test_preds = pl.DataFrame(best.predict(X_test))
    test_preds.columns = [f"{str(model).split('(')[0]}_predictions"] # to identify which model made this prediction

    return train_preds, test_preds, valid_preds, best

# %%
def stack_simple_models(X_train: pl.DataFrame, X_valid: pl.DataFrame, X_test: pl.DataFrame, y_train, y_valid) -> (pl.DataFrame, pl.DataFrame, pl.DataFrame):
    sgd_params = {"sgd__loss": ["squared_error", "huber", "epsilon_insensitive", "squared_epsilon_insensitive"],
                  "sgd__penalty": ["l2", "l1", "elasticnet", None], "sgd__alpha": np.arange(1e-4, 0.1, 0.001),
                  "sgd__learning_rate": ["constant", "optimal", "invscaling", "adaptive", "pa1", "pa2"],
                  "sgd__early_stopping": [True], "sgd__warm_start": [True]}
    rf_params = {"rf__loss": ["squared_error", "absolute_error", "huber", "quantile"], "rf__learning_rate": np.arange(1e-3, 3, 0.01),
                 "rf__n_estimators": np.arange(100, 500, 100), "rf__criterion": ["friedman_mse", "squared_error"],
                 "rf__max_depth": np.arange(3, 20, 1), "rf__max_features": [None, "sqrt", "log2"], "rf__warm_start": [True, False]}
    kneighbor_params = {"knn__n_neighbors": np.arange(2,20), "knn__weights": ["uniform", "distance"], "knn__algorithm": ['auto', 'ball_tree', 'kd_tree', 'brute'],
                        "knn__leaf_size": np.arange(10,50), "knn__p": [1, 2]}

    # Build each simple model and stack the predictions onto training, validation, and testing data
    lr_train, lr_test, lr_valid, lr = base_model_predictions(X_train, X_test, X_valid, y_train, y_valid, "lr", LinearRegression())
    lr_col_name = lr_train.columns[0]
    X_train, X_test, X_valid = X_train.hstack(lr_train), X_test.hstack(lr_test), X_valid.hstack(lr_valid)

    sgd_train, sgd_test, sgd_valid, sgd = base_model_predictions(X_train, X_test, X_valid, y_train, y_valid, "sgd", SGDRegressor(max_iter=20_000), sgd_params)
    sgd_col_name = sgd_train.columns[0]
    X_train, X_test, X_valid = X_train.hstack(sgd_train), X_test.hstack(sgd_test), X_valid.hstack(sgd_valid)

    kn_train, kn_test, kn_valid, kneighbor = base_model_predictions(X_train, X_test, X_valid, y_train, y_valid, "knn", KNeighborsRegressor(n_jobs=-1), kneighbor_params)
    kn_col_name = kn_train.columns[0]
    X_train, X_test, X_valid = X_train.hstack(kn_train), X_test.hstack(kn_test), X_valid.hstack(kn_valid)

    rf_train, rf_test, rf_valid, rf = base_model_predictions(X_train, X_test, X_valid, y_train, y_valid, "rf", GradientBoostingRegressor(random_state=42), rf_params)
    rf_col_name = rf_train.columns[0]
    X_train, X_test, X_valid = X_train.hstack(rf_train), X_test.hstack(rf_test), X_valid.hstack(rf_valid)

    base_models = {lr_col_name: lr, sgd_col_name: sgd, kn_col_name: kneighbor, rf_col_name: rf}   # keyed by the REAL column name, not a short label
    return X_train, X_valid, X_test, base_models

# %%
# keras can't work with polars or pandas dataframes and needs to be a numpy array
def to_np(X_train: pl.DataFrame, y_train: pl.DataFrame,
          X_valid: pl.DataFrame, y_valid: pl.DataFrame,
          X_test: pl.DataFrame, y_test: pl.DataFrame) -> (np.array, np.array, np.array, np.array, np.array, np.array):
    X_train_np = X_train.to_numpy()
    X_valid_np = X_valid.to_numpy()
    y_train_np = y_train.to_numpy()
    y_valid_np = y_valid.to_numpy()
    X_test_np = X_test.to_numpy()
    y_test_np = y_test.to_numpy()

    return X_train_np, y_train_np, X_valid_np, y_valid_np, X_test_np, y_test_np

# %%
# Build Neural network
def build_simple_nn(X_train_np, y_train_np, X_valid_np, y_valid_np):
    tf.keras.backend.clear_session()
    tf.random.set_seed(42)
    normalizer = tf.keras.layers.Normalization(input_shape=X_train_np.shape[1:])
    normalizer.adapt(X_train_np)
    
    model = tf.keras.Sequential([
        normalizer,
        tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        tf.keras.layers.Dense(32, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        tf.keras.layers.Dense(16, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(1) # Output
    ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    history = model.fit(X_train_np, y_train_np, epochs=200, validation_data=(X_valid_np, y_valid_np), callbacks=[early_stop])
    model.summary()

    graph_loss(model, history, X_valid_np, y_valid_np)

    corr, _ = spearmanr(y_valid_np, model.predict(X_valid_np).flatten())
    print(f"Simple model Spearman: {corr}")

    return history, model, corr

# %%
def graph_loss(model, history, X_valid, y_valid):
    val_predictions = model.predict(X_valid[:10])
    val_true = y_valid[:10]
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='val loss')
    plt.legend()
    plt.title("Training Loss vs Validation Loss")
    plt.show()
    plt.scatter(range(len(val_predictions)), val_predictions, color='blue')
    plt.scatter(range(len(val_true)), val_true, color='red')
    plt.legend(['predictions', 'true values'])
    plt.title("Predictions vs Actual Values on Validation Set")
    plt.show()

# %%
def graph_loss_wd(model, history, X_valid_wide, X_valid_deep, y_valid):
    val_predictions = model.predict((X_valid_wide[:10], X_valid_deep[:10]))
    val_true = y_valid[:10]
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='val loss')
    plt.legend()
    plt.title("Training Loss vs Validation Loss")
    plt.show()
    plt.scatter(range(len(val_predictions)), val_predictions, color='blue')
    plt.scatter(range(len(val_true)), val_true, color='red')
    plt.legend(['predictions', 'true values'])
    plt.title("Predictions vs Actual Values on Validation Set")
    plt.show()

# %%
# Build wide-deep NN
def build_wd_model(X_train, y_train, X_valid, y_valid, wide_index: int, deep_index: int):
    X_train_wide = X_train[:, :wide_index]
    X_train_deep = X_train[:, deep_index:]
    X_valid_wide = X_valid[:, :wide_index]
    X_valid_deep = X_valid[:, deep_index:]

    # Callbacks
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(42)
    
    input_wide = tf.keras.layers.Input(shape=[wide_index])
    input_deep = tf.keras.layers.Input(shape=[X_train.shape[1]-deep_index])
    norm_layer_wide = tf.keras.layers.Normalization()
    norm_layer_deep = tf.keras.layers.Normalization()
    norm_wide = norm_layer_wide(input_wide)
    norm_deep = norm_layer_deep(input_deep)
    hidden1 = tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01))(norm_deep)
    hidden2 = tf.keras.layers.Dense(32, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01))(hidden1)
    hidden3 = tf.keras.layers.Dense(24, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.1))(hidden2)
    concat = tf.keras.layers.concatenate([norm_wide, hidden3])
    dropout = tf.keras.layers.Dropout(0.3)(concat)
    output = tf.keras.layers.Dense(1)(dropout)
    wd_model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])
    
    wd_optimizer = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.15)
    
    wd_model.compile(loss="mse", optimizer=wd_optimizer, metrics=["RootMeanSquaredError"])
    
    norm_layer_wide.adapt(X_train_wide)
    norm_layer_deep.adapt(X_train_deep)
    wd_history = wd_model.fit((X_train_wide, X_train_deep), y_train, epochs=200,
                              validation_data=((X_valid_wide, X_valid_deep), y_valid), callbacks=[early_stop])

    wd_predictions = wd_model.predict((X_valid_wide[:10], X_valid_deep[:10]))
    wd_true = y_valid[:10]

    graph_loss_wd(wd_model, wd_history, X_valid_wide, X_valid_deep, y_valid)
    corr, _ = spearmanr(y_valid, wd_model.predict((X_valid_wide, X_valid_deep)).flatten())

    print(f"\nWide-Deep Spearman corr: {corr}")

    return wd_history, wd_model, corr

# %%
def build_position_model(pos):
    print(f"Building model for {pos}...")
    pos_combined = build_prediction_dataset(pos)
    
    pos_names = pos_combined.with_columns(pl.col("player_display_name"))
    
    X, y = pos_combined.drop(pl.col(["player_display_name","fantasy_points_ppr"])), pos_combined["fantasy_points_ppr"]
    
    X_cols = X.columns
    
    X_train, y_train, X_valid, y_valid, X_test, y_test, num_pipeline = ttv_scaled(X, y) # split data into training/validation/test and scale with num_pipeline
    X_train, X_valid, X_test, kmeans_model, pca = add_kmeans(X_train, X_valid, X_test) # Add kmeans
    X_train, X_valid, X_test, base_models = stack_simple_models(X_train, X_valid, X_test, y_train, y_valid) # Add LR, gradient boosted trees, and sgd regressor
    X_train_np, y_train_np, X_valid_np, y_valid_np, X_test_np, y_test_np = to_np(X_train, y_train, X_valid, y_valid, X_test, y_test) # Convert to np for model building
    history, model, simple_corr = build_simple_nn(X_train_np, y_train_np, X_valid_np, y_valid_np) # Build simple model
    wd_history, wd_model, wd_corr = build_wd_model(X_train_np, y_train_np, X_valid_np, y_valid_np, 7,5) # Build wide-deep model architecture to compare against simple model and graph predictions

    simple_preds = model.predict(X_valid_np).flatten()
    wd_preds = wd_model.predict((X_valid_np[:, :7], X_valid_np[:, 5:])).flatten()
    
    blended_preds = 0.5 * simple_preds + 0.5 * wd_preds
    blended_corr, _ = spearmanr(y_valid_np, blended_preds)
    
    print(f"Simple: {simple_corr:.3f}, WD: {wd_corr:.3f}, Blended: {blended_corr:.3f}")

    artifacts = {
        "num_pipeline": num_pipeline,
        "pca": pca,
        "kmeans_model": kmeans_model,
        "base_models": base_models,
        "simple_model": model,
        "wd_model": wd_model,
        "simple_corr": simple_corr,
        "wd_corr": wd_corr,
        "feature_cols": X_cols,   # column order/names, needed to rebuild new data consistently
        "wide_index": 7,
        "deep_index": 5,
    }

    return artifacts, pos_names

# %%
qb_artifacts, qb_names = build_position_model(qbs)
# Out:
# Building model for shape: (2_078, 44)
# ┌────────────────┬────────┬───────┬─────────────┬───┬───────────────┬────────────────┬────────────────┬────────────────┐
# │ player_display ┆ season ┆ games ┆ completions ┆ … ┆ has_cpoe_data ┆ passing_epa_tr ┆ passing_cpoe_t ┆ one_year_fpp_t │
# │ _name          ┆ ---    ┆ ---   ┆ ---         ┆   ┆ ---           ┆ end            ┆ rend           ┆ rend           │
# │ ---            ┆ i32    ┆ i32   ┆ i32         ┆   ┆ bool          ┆ ---            ┆ ---            ┆ ---            │
# │ str            ┆        ┆       ┆             ┆   ┆               ┆ f64            ┆ f64            ┆ f64            │
# ╞════════════════╪════════╪═══════╪═════════════╪═══╪═══════════════╪════════════════╪════════════════╪════════════════╡
# │ Troy Aikman    ┆ 1999   ┆ 14    ┆ 263         ┆ … ┆ false         ┆ 0.0            ┆ 0.0            ┆ 0.0            │
# ...

# %%
rb_artifacts, rb_names = build_position_model(rbs)
# Out:
# Building model for shape: (3_903, 38)
# ┌──────────────────┬────────┬───────┬─────────┬───┬────────────────┬─────────────────┬──────────────────┬──────────────┐
# │ player_display_n ┆ season ┆ games ┆ carries ┆ … ┆ yards_per_rush ┆ targets/carries ┆ one_year_fpp_tre ┆ is_workhorse │
# │ ame              ┆ ---    ┆ ---   ┆ ---     ┆   ┆ ---            ┆ ---             ┆ nd               ┆ ---          │
# │ ---              ┆ i32    ┆ i32   ┆ i32     ┆   ┆ f64            ┆ f64             ┆ ---              ┆ bool         │
# │ str              ┆        ┆       ┆         ┆   ┆                ┆                 ┆ f64              ┆              │
# ╞══════════════════╪════════╪═══════╪═════════╪═══╪════════════════╪═════════════════╪══════════════════╪══════════════╡
# │ Abdul-Karim      ┆ 1999   ┆ 13    ┆ 143     ┆ … ┆ 3.111888       ┆ 0.153846        ┆ 0.0              ┆ false        │
# ...

# %%
te_artifacts, te_names = build_position_model(tes)
# Out:
# Building model for shape: (3_148, 37)
# ┌─────────────────┬────────┬───────┬─────────┬───┬─────────────────┬────────────────┬─────────────────┬────────────────┐
# │ player_display_ ┆ season ┆ games ┆ carries ┆ … ┆ fantasy_points_ ┆ yards_per_rush ┆ targets/carries ┆ one_year_fpp_t │
# │ name            ┆ ---    ┆ ---   ┆ ---     ┆   ┆ ppr             ┆ ---            ┆ ---             ┆ rend           │
# │ ---             ┆ i32    ┆ i32   ┆ i32     ┆   ┆ ---             ┆ f64            ┆ f64             ┆ ---            │
# │ str             ┆        ┆       ┆         ┆   ┆ f64             ┆                ┆                 ┆ f64            │
# ╞═════════════════╪════════╪═══════╪═════════╪═══╪═════════════════╪════════════════╪═════════════════╪════════════════╡
# │ Stephen         ┆ 1999   ┆ 15    ┆ 0       ┆ … ┆ 79.4            ┆ NaN            ┆ 0.0             ┆ 0.0            │
# ...

# %%
wr_artifacts, wr_names = build_position_model(wrs)
# Out:
# Building model for shape: (5_643, 37)
# ┌─────────────────┬────────┬───────┬─────────┬───┬─────────────────┬────────────────┬─────────────────┬────────────────┐
# │ player_display_ ┆ season ┆ games ┆ carries ┆ … ┆ fantasy_points_ ┆ yards_per_rush ┆ targets/carries ┆ one_year_fpp_t │
# │ name            ┆ ---    ┆ ---   ┆ ---     ┆   ┆ ppr             ┆ ---            ┆ ---             ┆ rend           │
# │ ---             ┆ i32    ┆ i32   ┆ i32     ┆   ┆ ---             ┆ f64            ┆ f64             ┆ ---            │
# │ str             ┆        ┆       ┆         ┆   ┆ f64             ┆                ┆                 ┆ f64            │
# ╞═════════════════╪════════╪═══════╪═════════╪═══╪═════════════════╪════════════════╪═════════════════╪════════════════╡
# │ Derrick         ┆ 1999   ┆ 16    ┆ 2       ┆ … ┆ 163.4           ┆ 41.0           ┆ 52.5            ┆ 0.0            │
# ...

# %%
def rank_season(raw_pos_df, season, artifacts, id_cols=["player_display_name", "season"]):
    """
    Ranks players for a given season using an already-built position model.
    `raw_pos_df` should be the position-specific dataframe BEFORE build_prediction_dataset
    (i.e. the same shape as `qbs`/`rbs`/etc. after feature engineering, but not yet paired
    with a next-season target).
    """
    # 1. Pull just the requested season's rows
    season_df = raw_pos_df.filter(pl.col("season") == season)
    if season_df.shape[0] == 0:
        raise ValueError(f"No rows found for season {season}")

    names = season_df.select(id_cols)
    X_new = season_df.select(artifacts["feature_cols"])  # same column order used in training

    # 2. Transform-only through every fitted preprocessing step (never re-fit!)
    X_new_scaled = pl.DataFrame(artifacts["num_pipeline"].transform(X_new), schema=artifacts["feature_cols"])

    X_new_pca = artifacts["pca"].transform(X_new_scaled.to_numpy())
    cluster_distances = pl.DataFrame(artifacts["kmeans_model"].transform(X_new_pca))
    cluster_distances.columns = [f"cluster_{i+1}_distance" for i in range(artifacts["kmeans_model"].n_clusters)]
    X_new_scaled = X_new_scaled.hstack(cluster_distances)

    for name, base_model in artifacts["base_models"].items():
        print(base_model)
        preds = pl.DataFrame(base_model.predict(X_new_scaled))
        preds.columns = [f"{name}"]
        X_new_scaled = X_new_scaled.hstack(preds)

    # 3. Predict with whichever model won on validation Spearman correlation
    X_new_np = X_new_scaled.to_numpy()
    if artifacts["simple_corr"] >= artifacts["wd_corr"]:
        predictions = artifacts["simple_model"].predict(X_new_np).flatten()
    else:
        wide_idx, deep_idx = artifacts["wide_index"], artifacts["deep_index"]
        predictions = artifacts["wd_model"].predict(
            (X_new_np[:, :wide_idx], X_new_np[:, deep_idx:])
        ).flatten()

    # 4. Attach predictions to names and rank
    rankings = names.with_columns(
        pl.Series("predicted_points", predictions)
    ).sort("predicted_points", descending=True)

    rankings = rankings.with_row_index(name="pos_rank", offset=1)

    return rankings

# %%
def calculate_vorp(position_rankings: dict[str: pl.DataFrame], replacement_rank: dict[str: int]) -> pl.DataFrame:
    """
    rankings_by_position: {"QB": qb_rankings, "RB": rb_rankings, "TE": te_rankings, "WR": wr_rankings}
    replacement_rank: e.g. {"QB": 12, "RB": 30, "TE": 12, "WR": 30}
        (the rank at each position considered "replacement level" — roughly
        the last starter in a typical league; RB/WR go deeper since more
        are started, and are scarcer)
    """
    all_players = []
    for pos, df in position_rankings.items():
        df = df.sort("predicted_points", descending=True)
        replacement_value = df["predicted_points"][replacement_rank[pos]-1] # find the Nth best player from the positoion table
        df = df.with_columns(
            (pl.col("predicted_points") - replacement_value).alias("vorp"),
            (pl.lit(pos)).alias("position")
        )
        all_players.append(df)

    combined = pl.concat(all_players)
    combined = combined.sort("vorp", descending=True).with_row_index(name="overall_rank", offset=1)
    return combined

# %%
# add all artifacts from models into a dictionary
positions_dict = {
    "QB": {
        "DataFrame": qbs,
        "Artifacts": qb_artifacts,
    },
    "RB": {
        "DataFrame": rbs,
        "Artifacts": rb_artifacts,
    },
    "TE": {
        "DataFrame": tes,
        "Artifacts": te_artifacts,
    },
    "WR": {
        "DataFrame": wrs,
        "Artifacts": wr_artifacts,
    }
}

replacement_ranks = {"QB": 12, "RB": 30, "TE": 12, "WR": 30}

# %%
def get_season_rankings(positions, season, replacement_ranks) -> pl.DataFrame:
    #TODO: write a function that iterates over artifacts and dataframes to get predictions, calculate vorp and return rankings
    position_rankings = dict()
    for pos, pos_dict in positions.items():
        df = pos_dict['DataFrame']
        artifacts = pos_dict['Artifacts']
        position_rankings[pos] = rank_season(df, season, artifacts)

    final_df = calculate_vorp(position_rankings, replacement_ranks)
    final_df = final_df.drop(pl.col("season"))

    final_df = final_df.select(['player_display_name', 'predicted_points', 'vorp', 'position', 'pos_rank', 'overall_rank'])

    return final_df

# %%
rankings_2023 = get_season_rankings(positions_dict, 2023, replacement_ranks)
rankings_2024 = get_season_rankings(positions_dict, 2024, replacement_ranks)
rankings_2025_v2 = get_season_rankings(positions_dict, 2025, replacement_ranks)
# Out:
# Pipeline(steps=[('lr', LinearRegression())])
# Pipeline(steps=[('sgd',
#                  SGDRegressor(alpha=np.float64(0.0541), early_stopping=True,
#                               learning_rate='constant', loss='huber',
#                               max_iter=20000, penalty=None, warm_start=True))])
# Pipeline(steps=[('knn',
#                  KNeighborsRegressor(algorithm='kd_tree',
#                                      leaf_size=np.int64(30), n_jobs=-1,
#                                      n_neighbors=np.int64(19)))])
# Pipeline(steps=[('rf',
#                  GradientBoostingRegressor(learning_rate=np.float64(0.33099999999999996),
#                                            loss='huber', max_depth=np.int64(11),
#                                            max_features='log2',
#                                            n_estimators=np.int64(400),
#                                            random_state=42, warm_start=True))])
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...

# %%
rankings_2023.show(20)
rankings_2024.show(20)
rankings_2025_v2.show(20)
# Out:
# <div><style>
# .dataframe > thead > tr,
# .dataframe > tbody > tr {
#   text-align: right;
#   white-space: pre-wrap;
# }
# </style>
# ...

# %%
rankings_2025.write_csv("Weighted 2025 Rankings.csv")
